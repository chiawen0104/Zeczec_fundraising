# %%
# 上傳csv檔案
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55eb9a4c-d148-4bdf-82b4-04bb0c9e4190" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55eb9a4c-d148-4bdf-82b4-04bb0c9e4190">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CleanData_for_EDA.csv to CleanData_for_EDA.csv

# %%
# 將csv轉成data frame
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['CleanData_for_EDA.csv']))
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#      category  success  target money  ...  set_num  set_price  time_expected
# 0          遊戲        1         10000  ...        3       1180      31.416667
# 1          設計        1        150000  ...        6     3680.0     125.250000
# 2          時尚        1       1500000  ...        5       1500      97.521528
# 3          教育        1         30000  ...       11        777       7.541667
# 4          表演        1           666  ...        5        650       8.500000
# ...       ...      ...           ...  ...      ...        ...            ...
# 4559       音樂        0         35000  ...       12      550.0      11.000000
# 4560     插畫漫畫        0         80000  ...        9        500      21.000000
# 4561       設計        0         20000  ...        4     1500.0      53.000000
# 4562       音樂        0         20000  ...       10      850.0     213.000000
# 4563       設計        0         35000  ...        7        200     107.000000
#
# [4564 rows x 18 columns]

# %%
pip install dataprep
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 366 kB 54.6 MB/s
# ...
#      |████████████████████████████████| 158 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 848 kB 42.5 MB/s
# ...
#      |████████████████████████████████| 10.9 MB 42.8 MB/s
# ...
#      |████████████████████████████████| 943 kB 39.7 MB/s
# ...
#      |████████████████████████████████| 719 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 48.0 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 23.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 63.5 MB/s
# ...
#      |████████████████████████████████| 160 kB 69.4 MB/s
# ...
#      |████████████████████████████████| 192 kB 66.5 MB/s
# ...
#      |████████████████████████████████| 132 kB 59.3 MB/s
# ...
#      |████████████████████████████████| 49 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 28.2 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 59.4 MB/s
# ...

# %%
from dataprep import eda as dpeda
report = dpeda.create_report(df, title='Zeczec Data')
report.save('Zeczec_Dataset_Dataprep')
# Out:
# Report has been saved to Zeczec_Dataset_Dataprep.html!
